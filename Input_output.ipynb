# %%
dbutils.widgets.text("postal_code", "")
postal_code = dbutils.widgets.get("postal_code")

result = dbutils.notebook.run(
    "/Workspace/Users/kili.schreiner@gmail.com/Try_out_folder/person3",
    300,
    {"postal_code": postal_code}
)

print(result)


dbutils.notebook.exit(result)
