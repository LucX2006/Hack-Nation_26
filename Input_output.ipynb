# %%
dbutils.widgets.text("my_input_arg", "default_value")
content = dbutils.widgets.get("my_input_arg")
file_name = "output.txt"

with open(file_name, "w") as file:
    file.write(content)
print("Done,databricks")
